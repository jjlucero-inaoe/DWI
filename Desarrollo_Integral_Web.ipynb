# %% [markdown]
# <a href="https://colab.research.google.com/github/jjlucero-inaoe/DWI/blob/master/Desarrollo_Integral_Web.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvenidos al primer trabajo colaborativo que va a desarrollar como grupo
#
# ---
#
# empresarial

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen
imagen = cv2.imread('gato.jpg')

# Convertir a float32 y normalizar a rango [0,1]
imagen_norm = imagen.astype(np.float32) / 255.0

# Aplicar la transformación: (x/255)^(1/3) * 255
imagen_modificada = np.power(imagen_norm, 1/3.0) * 255.0

# Convertir a uint8
imagen_modificada = imagen_modificada.astype(np.uint8)

# Convertir a RGB para mostrar bien con matplotlib
imagen_rgb = cv2.cvtColor(imagen_modificada, cv2.COLOR_BGR2RGB)

# Mostrar imagen
plt.imshow(imagen_rgb)
plt.axis('off')
plt.title("Contraste no lineal: (x/255)^(1/3) * 255")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen
imagen = cv2.imread('jlngro.png')

# Convertir a float32 y normalizar a rango [0,1]
imagen_norm = imagen.astype(np.float32) / 255.0

# Aplicar la transformación: (x/255)^(1/3) * 255
imagen_modificada = np.power(imagen_norm, 1/3.0) * 255.0

# Convertir a uint8
imagen_modificada = imagen_modificada.astype(np.uint8)

# Convertir a RGB para mostrar bien con matplotlib
imagen_rgb = cv2.cvtColor(imagen_modificada, cv2.COLOR_BGR2RGB)

# Mostrar imagen
plt.imshow(imagen_rgb)
plt.axis('off')
plt.title("Contraste no lineal: (x/255)^(1/3) * 255")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen
imagen = cv2.imread('gato.jpg')

# Convertir a float32 y normalizar a rango [0,1]
imagen_norm = imagen.astype(np.float32) / 255.0

# Aplicar la transformación: (x/255)^(1/3) * 255
imagen_modificada = np.power(imagen_norm, 2) * 255.0

# Convertir a uint8
imagen_modificada = imagen_modificada.astype(np.uint8)

# Convertir a RGB para mostrar bien con matplotlib
imagen_rgb = cv2.cvtColor(imagen_modificada, cv2.COLOR_BGR2RGB)

# Mostrar imagen
plt.imshow(imagen_rgb)
plt.axis('off')
plt.title("Contraste no lineal: (x/255)^(2) * 255")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar imagen
imagen = cv2.imread('jlngro.png')

# Convertir a float32 y normalizar a rango [0,1]
imagen_norm = imagen.astype(np.float32) / 255.0

# Aplicar la transformación: (x/255)^(1/3) * 255
imagen_modificada = np.power(imagen_norm, 2) * 255.0

# Convertir a uint8
imagen_modificada = imagen_modificada.astype(np.uint8)

# Convertir a RGB para mostrar bien con matplotlib
imagen_rgb = cv2.cvtColor(imagen_modificada, cv2.COLOR_BGR2RGB)

# Mostrar imagen
plt.imshow(imagen_rgb)
plt.axis('off')
plt.title("Contraste no lineal: (x/255)^(2) * 255")
plt.show()

# %% [markdown]
# Objetivo desarrollar un mini programa basado en Inteligencia Artificial que realice análisis de imágenes básicas.

# %%
import cv2
imagen = cv2.imread('perro.jpg')

# %%
import cv2
from matplotlib import pyplot as plt

# Carga la imagen
# Asegúrate de que 'mi_imagen.jpg' sea el nombre exacto de tu archivo
img = cv2.imread('perro.jpg')

# Convierte de BGR a RGB para Matplotlib
#img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Muestra la imagen
plt.imshow(img_rgb)
plt.axis('off') # Opcional: Ocultar ejes
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6b70e364bcf3> in <cell line: 0>()
#      10
#      11 # Muestra la imagen
# ---> 12 plt.imshow(img_rgb)
#      13 plt.axis('off') # Opcional: Ocultar ejes
#      14 plt.show()
#
# NameError: name 'img_rgb' is not defined

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('juanluisnegro.png')

# Invertir colores (hacer negativo)
negativo = 255 - imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: gato.jpg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2310180901> in <cell line: 0>()
#       6
#       7 # Invertir colores (hacer negativo)
# ----> 8 negativo = 255 - imagen
#       9
#      10 # Convertir a RGB para visualizar con matplotlib
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('gato.jpg')

# Invertir colores (hacer negativo)
negativo = 128 + imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: gato.jpg")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('jlngro.png')

# Invertir colores (hacer negativo)
negativo = 128 + imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: jlngro.png")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('gato.jpg')

# Invertir colores (hacer negativo)
negativo = 2 * imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: gato.jpg")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('jlngro.png')

# Invertir colores (hacer negativo)
negativo = 2 * imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: jlngro.png")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen
imagen = cv2.imread('gato.jpg')

# Reducir el contraste: dividir todos los valores de píxel entre 2
imagen_baja_contraste = (imagen / 2).astype('uint8')

# Convertir a RGB para visualizar correctamente con matplotlib
imagen_rgb = cv2.cvtColor(imagen_baja_contraste, cv2.COLOR_BGR2RGB)

# Mostrar la imagen con menor contraste
plt.imshow(imagen_rgb)
plt.axis('off')
plt.title("Imagen con menor contraste (x / 2)")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen
imagen = cv2.imread('jlngro.png')

# Reducir el contraste: dividir todos los valores de píxel entre 2
imagen_baja_contraste = (imagen / 2).astype('uint8')

# Convertir a RGB para visualizar correctamente con matplotlib
imagen_rgb = cv2.cvtColor(imagen_baja_contraste, cv2.COLOR_BGR2RGB)

# Mostrar la imagen con menor contraste
plt.imshow(imagen_rgb)
plt.axis('off')
plt.title("Imagen con menor contraste (x / 2)")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('jlngro.png')

# Invertir colores (hacer negativo)
negativo = 255 - imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: jlngro.png")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('gato.jpg')

# Invertir colores (hacer negativo)
negativo = 128 - imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: gato.jpg")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('perro.jp')

# Invertir colores (hacer negativo)
negativo = 128 - imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: jlngro.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1104482423> in <cell line: 0>()
#       6
#       7 # Invertir colores (hacer negativo)
# ----> 8 negativo = 128 - imagen
#       9
#      10 # Convertir a RGB para visualizar con matplotlib
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen en BGR
imagen = cv2.imread('perro.jpg')

# Invertir colores (hacer negativo)
negativo = 255 - imagen

# Convertir a RGB para visualizar con matplotlib
negativo_rgb = cv2.cvtColor(negativo, cv2.COLOR_BGR2RGB)

# Mostrar imagen negativa
plt.imshow(negativo_rgb)
plt.axis('off')
plt.title("Imagen Negativa: siames.jpg")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen (OpenCV la lee en BGR)
imagen = cv2.imread('perro.jpg')

# Convertir de BGR a RGB para que se vea bien con matplotlib
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagen_rgb)
plt.axis('off')  # Quitar los ejes
plt.title("Imagen: siames.jpg")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen (OpenCV la lee en BGR)
imagen = cv2.imread('perro.jpg')

# Convertir de BGR a RGB para que se vea bien con matplotlib
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagen_rgb)
plt.axis('off')  # Quitar los ejes
plt.title("Imagen: gato.jpg")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()

import cv2
import matplotlib.pyplot as plt

# Suponiendo que subiste una imagen llamada 'gato.jpg'
img = cv2.imread('perro.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-51ea838e-e031-4ae2-955a-83a85368abaf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51ea838e-e031-4ae2-955a-83a85368abaf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img="perro.jpg"
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-4bde9271ae01> in <cell line: 0>()
#       1 img="perro.jpg"
#       2 from google.colab.patches import cv2_imshow
# ----> 3 cv2_imshow(img)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'str' object has no attribute 'clip'

# %%
from google.colab import files
uploaded = files.upload()

import cv2
import matplotlib.pyplot as plt

# Suponiendo que subiste una imagen llamada 'juan1.jpg'
img = cv2.imread('juan1.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-b5b10cc1-83e7-41a5-9354-2b652a43f700" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5b10cc1-83e7-41a5-9354-2b652a43f700">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
